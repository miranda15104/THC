# %% [markdown]
# <a href="https://colab.research.google.com/github/miranda15104/THC/blob/main/ayuda_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
while not(opcion==4):
 opcion=int(input("***Menu*** \n1.Convertir unidades de longitud \n2.Convertir unidades de masa \n3. Convertir unidades de tiempo. \n4. salir " "¿que quieres hacer?"))

 if opcion==1:
  longuitud=int(input("***SI o sing*** \n1. SI al Sistema Inglés \n2. del Sistema Inglés a SI" " ¿cual conversion gustas hacer?" ))

  if longuitud==1:
    SIasi=int(input("***escoge a que medida de lo que quieres convertir*** \n1. pies \n2. millaski  \n3. yarda \n4. pulgada \n5.millasme11"))

    if SIasi== 1:
      metros=int(input("ingresa la cantidad de metros que quieres covertir a pies:"))
      pies=metros*3.28084
      print(metros, "metros equivalen a ", pies, "pies")
    elif SIasi== 2:
      kilometros=int(input("ingresa la cantidad de kilometros que quieres convertir a millas:"))
      millas=kilometros*0.621371
      print(millas,"millas equivalen a", kilometros, "kilometros")
    elif SIasi== 3:
      metros=int(input("ingresa la cantidad de metros que quieres convertir a yardas:"))
      yardas=metros*1.09361
      print(yardas,"yardas equivalen a", metros, "metros")

    elif SIasi== 4:
      centimetros=int(input("ingresa la cantidad de centimetros que quieres convertir a pulgadass:"))
      pulgadas=centimetros*0.393701
      print(centimetros,"metros equivalen a", pulgadas, "yardas")
    elif SIasi== 5:
      metrosmi=int(input("ingresa la cantidad de metros que quieres convertir a millas:"))
      millass=metrosmi*0.000621371
      print(metrosmi,"metros equivalen a", millass , "millas")
    else:
      print("ingresa una opcion valida")
  elif longuitud==2:
    siASI=int(input("**escoge a que medida del Sistema Inglés lo quieres convertir***  \n1. metros a pies\n2. centimetros a pies \n3. kilometros \n4. metros a yarda \n5. centimetros a pulgadas"))
    if siASI== 1:
      piesi=int(input("ingresa la cantidad de pies que quieres covertir a metros:"))
      metrosi=piesi*0.30482
      print(metrosi, "pies equivalen a ", piesi, "metros")
    elif siASI== 2:
      piesc=int(input("ingresa la cantidad de pies que quieres convertir a centimetros:"))
      centimetros=piesc*30.48
      print(piesc,"pies equivalen a", centimetros, "centimeros")
    elif siASI==3:
      millasi=int(input("ingresa la cantidad de millas que quieres convertir a kilometros"))
      kilometrosi= millasi*1.60934
      print(millasi, "millas equivalen a ", kilometrosi, " kilometros")
    elif siASI==4:
      yardai=int(input("ingresa la cantidad de yardas que quieres convertir a metros"))
      metrosi=yardai*0.9144
      print(yardai, "yardas equivalen a ",metrosi, " metros")
    elif siASI==5:
      pulgada=int(input("ingresa la cantidad de pulgadas que quieres convertir a centimetros"))
      centimetro= pulgada*2.54
      print(pulgada,"pulgadas equivalen a ", centimetro, "centimetros")
    else:
      print("Ingresa una opción válida")
  else:
            print("Ingresa una opción válida")



 elif opcion==2:

  Masa=int(input("***SI o sistema ingles*** \n1. SI al Sistema Inglés \n2. del Sistema Inglés a SI" " ¿cual conversion quieres hacer?"))
  if Masa==1:
    SisIasi=int(input("***escoge a que medida de lo que quieres convertir*** \n1. libra \n2. onzas \n3. tonelada "))
    if SisIasi==1:
      gramos=int(input("ingresa la cantidad de gramos que quieres convertir a libras:"))
      libras=gramos*0.00220462
      print(gramos,"gramos equivalen a", libras, "libras")
    if SisIasi==2:
      gramoso=int(input("ingresa la cantidad de gramos que quieres convertir a onzas:"))
      onzas=gramoso*0.035274
      print(gramoso,"gramos equivalen a", onzas, "onzas")
    if SisIasi==3:
      kilogramos=int(input("ingresa la cantidad de kilogramos que quieres convertir a toneladas:"))
      toneladas=kilogramos*0.001
      print(kilogramos,"kilogramos equivalen a", toneladas, "toneladas")
    else:
      print("ingresa una opcion valida")

  else:
      print("ingresa una opcion valida")


  if Masa==2:
      sistemIaSI=int(input("***escoge a que medida de lo que quieres convertir*** \n1. gramoli \n2. gramoon \n3. kilogramos  " "¿a que medida del SI lo quieres pasar"))
      if sistemIaSI==1:
       libra=int(input("ingresa la cantidad de libras que quieres convertir a gramos:"))
       gramosli=libra*453.592
       print(libra, "libras equivalen a", gramosli, "gramos")
      if sistemIaSI==2:
       onza=int(input("ingresa la cantidad de onzas que quieres convertir a gramos:"))
       gramoson=onza*28.3495
       print(onza, "onzas equivalen a", gramoson, "gramos")
      if sistemIaSI==3:
       toneladak=int(input("ingresa la cantidad de toneladas que quieres convertir a kilogramos:"))
       kilogramost=toneladak*1000
       print(toneladak, "toneladas equivalen a", kilogramost, "kilogramos")
      else:
        ("ingresa una opcion valida")
  else:
    ("ingresa una opcion valida")

 elif opcion==3:
    tiempo=int(input("¿quieres convertir de mas grande a pequeño o vicebersa?""***vamos a convertir unidades de tiempo***  \n1. covertir de grande a pequeño \n2. convertir de pequeño a grande "))
    if tiempo==1:
      gap=int(input("***escoge que unidad quieres convertir*** \n1. dias a hora \n2. dias a minutos \n3. dias segundos \n4. horas a minutos \n5. horas a segundos \n6. horas a milisegundos \n7. minutos a segundos \n8. minutos a milisegundos \n9. segundos a milisegundos"))
      if gap==1:
       dias=int(input("ingresa la cantidad de dias que quieres convertir a horas:"))
       horas=dias*24
       print(dias,"dias equivalen a", horas, "horas")
      if gap==2:
       diasm=int(input("ingresa la cantidad de dias que quieres convertir a minutos:"))
       minutos=diasm*1440
       print(diasm,"dias equivalen a", minutos, "minutos")
      if gap==3:
       diass=int(input("ingresa la cantidad de dias que quieres convertir a segundos:"))
       segundos=diass*86400
       print(diass,"dias equivalen a", segundos, "segundos")
      if gap==4:
       horasm=int(input("ingresa la cantidad de horas que quieres convertir a minutos:"))
       minutosh=horasm*60
       print(horasm,"horas equivalen a", minutosh, "minutos")
      if gap==5:
       horass=int(input("ingresa la cantidad de horas que quieres convertir a segundos:"))
       segundosh=horass*3600
       print(horass,"horas equivalen a", segundosh, "segundos")
      if gap==6:
       horasm=int(input("ingresa la cantidad de horas que quieres convertir a milisegundos:"))
       milisegundos=horasm*3600000
       print(horasm,"horas equivalen a", segundosh, "milisegundos")
      if gap==7:
       minutosse=int(input("ingresa la cantidad de minutos que quieres convertir a segundos:"))
       segundosmm=minutosse*60
       print(minutosse,"minutos equivalen a", segundosmm, "segundos")
      if gap==8:
       minutosmi=int(input("ingresa la cantidad de minutos que quieres convertir a milisegundos:"))
       milisegundosm=minutosmi*60000
       print(minutosmi,"minutos equivalen a ", milisegundosm, " milisegundos")
      if gap==9:
       segundosmi=int(input("ingresa la cantidad de segundos que quieres convertir a milisegundos:"))
       milisegundoss=segundosmi*1000
       print(segundosmi,"minutos equivalen a ", milisegundoss, " milisegundos")
      else:
        print("ingrese una opcion valida")

    elif tiempo==2:
      pag=int(input("***escoge que unidad quieres convertir*** \n1. milisegundos a segundos \n2. milisegundos a minutos \n3. milisegundos a horas \n4. milisegundos a dias \n5.  segundos a minutos  \n6. segundos a horas  \n7. segundos a dias  \n8.  minutos a horas   \n9. minutos a dias  \n10. horas a dias"))
      if pag==1:
       milisegundosS=int(input("ingresa la cantidad de milisegundos que quieres convertir a segundos:"))
       segundosM=milisegundosS/1000
       print(milisegundosS, "milisegundos equivalen a ", segundosM,  " segundos")
      if pag==2:
       milisegundosM=int(input("ingresa la cantidad de milisegundos que quieres convertir a minutos:"))
       minutosM=milisegundosM/60000
       print(milisegundosM, "milisegundos equivalen a ", minutosM,  " minutos")
      if pag==3:
       milisegundosH=int(input("ingresa la cantidad de milisegundos que quieres convertir a horas:"))
       horasM=milisegundosH/3600000
       print(milisegundosH, "milisegundos equivalen a ", horasM,  " horas")
      if pag==4:
       milisegundosD=int(input("ingresa la cantidad de milisegundos que quieres convertir a dias:"))
       diasM=milisegundosD/86400000
       print(milisegundosD, "milisegundos equivalen a ", diasM,  " dias")
      if pag==5:
       SegundosM=int(input("ingresa la cantidad de segundos que quieres convertir a minutos:"))
       MinutosM=SegundosM/60
       print(SegundosM, "segundos equivalen a ", MinutosM,  " minutos")
      if pag==6:
       SegundosH=int(input("ingresa la cantidad de segundos que quieres convertir a horas:"))
       HorasS=SegundosH/3600
       print(SegundosH, "segundos equivalen a ", HorasS,  " horas")
      if pag==7:
       SegundosD=int(input("ingresa la cantidad de segundos que quieres convertir a dias:"))
       DiasS=SegundosD/86400
       print(SegundosD, "segundos equivalen a ", DiasS,  " dias")
      if pag==8:
       MinutosH=int(input("ingresa la cantidad de minutos que quieres convertir a horas:"))
       HorasM=MinutosH/60
       print(MinutosH, "minutoss equivalen a ", HorasM,  " horas")
      if pag==9:
       MinutosDi=int(input("ingresa la cantidad de minutos que quieres convertir a dias:"))
       DiasMI=MinutosDi/1440
       print(MinutosDi, "minutos equivalen a ", DiasMI,  " dias")
      if pag==10:
       Ho=int(input("ingresa la cantidad de horas que quieres convertir a dias:"))
       DiasHor=Ho/24
       print(Ho, "horas equivalen a ", DiasHor,  " dias")
      else:
        print("esa opcion no esta en las variables")



        pass
    elif opcion == 4:
     print("Saliendo del programa.")
 else:
      print("esa opcion no esta en el menu")
# Out:
# ***Menu***
# 1.Convertir unidades de longitud
# 2.Convertir unidades de masa
# 3. Convertir unidades de tiempo.
# 4. salir ¿que quieres hacer?3
# ¿quieres convertir de mas grande a pequeño o vicebersa?***vamos a convertir unidades de tiempo***
# 1. covertir de grande a pequeño
# 2. convertir de pequeño a grande 2
# ***escoge que unidad quieres convertir***
# 1. milisegundos a segundos
# 2. milisegundos a minutos
# 3. milisegundos a horas
# 4. milisegundos a dias
# 5.  segundos a minutos
# 6. segundos a horas
# 7. segundos a dias
# 8.  minutos a horas
# 9. minutos a dias
# 10. horas a dias2
# ingresa la cantidad de milisegundos que quieres convertir a minutos:1059
# 1059 milisegundos equivalen a  0.01765  minutos
# esa opcion no esta en las variables
