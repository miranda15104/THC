# %% [markdown]
# <a href="https://colab.research.google.com/github/miranda15104/THC/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 29/08/2014                    Guinea                     482
# 29/08/2014                   Nigeria                      15
# 29/08/2014              Sierra Leone                     935
# 29/08/2014                   Liberia                     322
# 05/09/2014                    Guinea                     604
# ...                              ...                     ...
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases    Boys   Girls  \
# Date
# 29/08/2014                    287.0       289.2         192.8   86.76   57.84
# 29/08/2014                      6.0         9.0           6.0    2.70    1.80
# 29/08/2014                    380.0       561.0         374.0  168.30  112.20
# 29/08/2014                    225.0       193.2         128.8   57.96   38.64
# 05/09/2014                    362.0       362.4         241.6  108.72   72.48
# ...                             ...         ...           ...     ...     ...
# 23/03/2016                      NaN      1890.6        1260.4  567.18  378.12
# 23/03/2016                      NaN         0.6           0.4    0.18    0.12
# 23/03/2016                      1.0         1.2           0.8    0.36    0.24
# 23/03/2016                      7.0        11.4           7.6    3.42    2.28
# 23/03/2016                      1.0         2.4           1.6    0.72    0.48
#
#             Adult Male  Adult Female  Old Male  Old Female
# Date
# 29/08/2014      173.52        115.68     28.92       19.28
# 29/08/2014        5.40          3.60      0.90        0.60
# 29/08/2014      336.60        224.40     56.10       37.40
# 29/08/2014      115.92         77.28     19.32       12.88
# 05/09/2014      217.44        144.96     36.24       24.16
# ...                ...           ...       ...         ...
# 23/03/2016     1134.36        756.24    189.06      126.04
# 23/03/2016        0.36          0.24      0.06        0.04
# 23/03/2016        0.72          0.48      0.12        0.08
# 23/03/2016        6.84          4.56      1.14        0.76
# 23/03/2016        1.44          0.96      0.24        0.16
#
# [2484 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df.shape
# Out:
# (2484, 11)

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df.head
# Out:
# <bound method NDFrame.head of                              Country  No. of confirmed cases  \
# Date
# 29/08/2014                    Guinea                     482
# 29/08/2014                   Nigeria                      15
# 29/08/2014              Sierra Leone                     935
# 29/08/2014                   Liberia                     322
# 05/09/2014                    Guinea                     604
# ...                              ...                     ...
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases    Boys   Girls  \
# Date
# 29/08/2014                    287.0       289.2         192.8   86.76   57.84
# 29/08/2014                      6.0         9.0           6.0    2.70    1.80
# 29/08/2014                    380.0       561.0         374.0  168.30  112.20
# 29/08/2014                    225.0       193.2         128.8   57.96   38.64
# 05/09/2014                    362.0       362.4         241.6  108.72   72.48
# ...                             ...         ...           ...     ...     ...
# 23/03/2016                      NaN      1890.6        1260.4  567.18  378.12
# 23/03/2016                      NaN         0.6           0.4    0.18    0.12
# 23/03/2016                      1.0         1.2           0.8    0.36    0.24
# 23/03/2016                      7.0        11.4           7.6    3.42    2.28
# 23/03/2016                      1.0         2.4           1.6    0.72    0.48
#
#             Adult Male  Adult Female  Old Male  Old Female
# Date
# 29/08/2014      173.52        115.68     28.92       19.28
# 29/08/2014        5.40          3.60      0.90        0.60
# 29/08/2014      336.60        224.40     56.10       37.40
# 29/08/2014      115.92         77.28     19.32       12.88
# 05/09/2014      217.44        144.96     36.24       24.16
# ...                ...           ...       ...         ...
# 23/03/2016     1134.36        756.24    189.06      126.04
# 23/03/2016        0.36          0.24      0.06        0.04
# 23/03/2016        0.72          0.48      0.12        0.08
# 23/03/2016        6.84          4.56      1.14        0.76
# 23/03/2016        1.44          0.96      0.24        0.16
#
# [2484 rows x 11 columns]>

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2484 entries, 29/08/2014 to 23/03/2016
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  2484 non-null   object
#  1   No. of confirmed cases   2484 non-null   int64
#  2   No. of confirmed deaths  1648 non-null   float64
#  3   Male Cases               2484 non-null   float64
#  4   Female Cases             2484 non-null   float64
#  5   Boys                     2484 non-null   float64
#  6   Girls                    2484 non-null   float64
#  7   Adult Male               2484 non-null   float64
#  8   Adult Female             2484 non-null   float64
#  9   Old Male                 2484 non-null   float64
#  10  Old Female               2484 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 232.9+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df.isnull()
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014    False                   False                    False
# 29/08/2014    False                   False                    False
# 29/08/2014    False                   False                    False
# 29/08/2014    False                   False                    False
# 05/09/2014    False                   False                    False
# ...             ...                     ...                      ...
# 23/03/2016    False                   False                     True
# 23/03/2016    False                   False                     True
# 23/03/2016    False                   False                    False
# 23/03/2016    False                   False                    False
# 23/03/2016    False                   False                    False
#
#             Male Cases  Female Cases   Boys  Girls  Adult Male  Adult Female  \
# Date
# 29/08/2014       False         False  False  False       False         False
# 29/08/2014       False         False  False  False       False         False
# 29/08/2014       False         False  False  False       False         False
# 29/08/2014       False         False  False  False       False         False
# 05/09/2014       False         False  False  False       False         False
# ...                ...           ...    ...    ...         ...           ...
# 23/03/2016       False         False  False  False       False         False
# 23/03/2016       False         False  False  False       False         False
# 23/03/2016       False         False  False  False       False         False
# 23/03/2016       False         False  False  False       False         False
# 23/03/2016       False         False  False  False       False         False
#
#             Old Male  Old Female
# Date
# 29/08/2014     False       False
# 29/08/2014     False       False
# 29/08/2014     False       False
# 29/08/2014     False       False
# 05/09/2014     False       False
# ...              ...         ...
# 23/03/2016     False       False
# 23/03/2016     False       False
# 23/03/2016     False       False
# 23/03/2016     False       False
# 23/03/2016     False       False
#
# [2484 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df['Country']
# Out:
# Date
# 29/08/2014                      Guinea
# 29/08/2014                     Nigeria
# 29/08/2014                Sierra Leone
# 29/08/2014                     Liberia
# 05/09/2014                      Guinea
#                         ...
# 23/03/2016                     Liberia
# 23/03/2016                       Italy
# 23/03/2016                     Liberia
# 23/03/2016                     Nigeria
# 23/03/2016    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df['Country']
cuantos=df.groupby("Country").size().reset_index(name="cuantos") #groupby agrega por pais en un mismo tamaño
cuantos
# Out:
#                     Country  cuantos
# 0                    Guinea      259
# 1                     Italy      141
# 2                   Liberia      364
# 3                      Mali      243
# 4                   Nigeria      255
# 5                   Senegal      254
# 6              Sierra Leone      259
# 7                     Spain      243
# 8            United Kingdom      221
# 9  United States of America      245

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

df['Country']
Cuantos=df.groupby("Country").size().reset_index(name="cuantos") #groupby agrega por pais en un mismo tamaño
Cuantos

plt.pie(Cuantos["cuantos"],labels=Cuantos["Country"],autopct="%0.1f%%")
plt.axis("equal")
plt.title("Distribución de ébola por países")
plt.savefig("Pastel_Paises.png",dpi=300,format="png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
# Out:
# Date
# 29/08/2014    False
# 29/08/2014    False
# 29/08/2014     True
# 29/08/2014    False
# 05/09/2014    False
#               ...
# 23/03/2016    False
# 23/03/2016    False
# 23/03/2016    False
# 23/03/2016    False
# 23/03/2016    False
# Name: Country, Length: 2484, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    2
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()
mean_values
# Out:
# 3104.9961089494163

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed cases"].mean()
mean_values
# Out:
# 7883.671814671815

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()
mean_values

SL.fillna(mean_values,inplace=True)
SL.isnull().sum()
# Out:
# <ipython-input-15-4b08731116d7>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL.fillna(mean_values,inplace=True)
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()
mean_values

SL.fillna(mean_values,inplace=True)
SL.isnull().sum()

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1) #quitar del eje 1 counttry
SL.head()
# Out:
# <ipython-input-16-3553997ab827>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL.fillna(mean_values,inplace=True)
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 29/08/2014                     935                    380.0       561.0
# 05/09/2014                    1146                    443.0       687.6
# 08/09/2014                    1234                    461.0       740.4
# 12/09/2014                    1287                    478.0       772.2
# 16/09/2014                    1464                    514.0       878.4
#
#             Female Cases    Boys   Girls  Adult Male  Adult Female  Old Male  \
# Date
# 29/08/2014         374.0  168.30  112.20      336.60        224.40     56.10
# 05/09/2014         458.4  206.28  137.52      412.56        275.04     68.76
# 08/09/2014         493.6  222.12  148.08      444.24        296.16     74.04
# 12/09/2014         514.8  231.66  154.44      463.32        308.88     77.22
# 16/09/2014         585.6  263.52  175.68      527.04        351.36     87.84
#
#             Old Female
# Date
# 29/08/2014       37.40
# 05/09/2014       45.84
# 08/09/2014       49.36
# 12/09/2014       51.48
# 16/09/2014       58.56

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()
mean_values

SL.fillna(mean_values,inplace=True)
SL.isnull().sum()
SL["No. of confirmed cases"].mean()

Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

plt.plot(Dates, NCC, "*--r",ms=5, label="infectados")
plt.plot(Dates,NCD, "*-b",  ms=5, label="decesos")
plt.grid()

plt.title("Avance de Ebola en Sierra Leona")
plt.ylabel("casos confirmados")
plt.xlabel("periodo de tiempo ")
plt.xticks(rotation=80, fontsize=7)
plt.legend()
plt.show()
# Out:
# <ipython-input-17-912572b0aa65>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL.fillna(mean_values,inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()
mean_values

SL.fillna(mean_values,inplace=True)
SL.isnull().sum()
SL["No. of confirmed cases"].mean()

Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

plt.plot(Dates, NCC, "*--r",ms=5, label="infectados")
plt.bar(Dates,NCC,color="red",label="infectados", alpha=0.4)

plt.plot(Dates,NCD, "*-b",  ms=5, label="decesos")
plt.bar(Dates,NCD, color="blue",label="decesos", alpha=0.7)
plt.grid()

plt.title("Avance de Ebola en Sierra Leona")
plt.ylabel("casos confirmados")
plt.xlabel("periodo de tiempo ")
plt.xticks(rotation=80, fontsize=7)
plt.legend()

plt.savefig("Sl.png",dpi=300,format="png")  #esta en content
plt.show()
# Out:
# <ipython-input-18-c562441ebb49>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL.fillna(mean_values,inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)
df["Country"]=="Sierra Leone"
SL=df[df["Country"]=="Sierra Leone"]
SL.isnull().sum()
mean_values=SL["No. of confirmed deaths"].mean()
mean_values

SL.fillna(mean_values,inplace=True)
SL.isnull().sum()
SL["No. of confirmed cases"].mean()

Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

fig=plt.figure(figsize=(12,6))
plt.plot(Dates, NCC, "*--r",ms=5, label="infectados")
plt.bar(Dates,NCC,color="red",label="infectados", alpha=0.4)

plt.plot(Dates,NCD, "*-b",  ms=5, label="decesos")
plt.bar(Dates,NCD, color="blue",label="decesos", alpha=0.7)
plt.grid()

plt.title("Avance de Ebola en Sierra Leona")
plt.ylabel("casos confirmados")
plt.xlabel("periodo de tiempo ")
plt.xticks(rotation=80, fontsize=7)
plt.legend()

plt.savefig("Slgrande.png",dpi=300,format="png")  #esta en content
plt.show()
# Out:
# <ipython-input-19-d469da88ad34>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL.fillna(mean_values,inplace=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df =pd.read_csv(url,sep=',',index_col=1)

SL.isnull().sum()
SL["No. of confirmed cases"].mean()

PIvsD=100*SL["No. of confirmed deaths"]/SL["No. of confirmed cases"]
SL["PIvsD"]=PIvsD

SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 29/08/2014                     935                    380.0       561.0
# 05/09/2014                    1146                    443.0       687.6
# 08/09/2014                    1234                    461.0       740.4
# 12/09/2014                    1287                    478.0       772.2
# 16/09/2014                    1464                    514.0       878.4
#
#             Female Cases    Boys   Girls  Adult Male  Adult Female  Old Male  \
# Date
# 29/08/2014         374.0  168.30  112.20      336.60        224.40     56.10
# 05/09/2014         458.4  206.28  137.52      412.56        275.04     68.76
# 08/09/2014         493.6  222.12  148.08      444.24        296.16     74.04
# 12/09/2014         514.8  231.66  154.44      463.32        308.88     77.22
# 16/09/2014         585.6  263.52  175.68      527.04        351.36     87.84
#
#             Old Female  recuprados         PR      PIvsD
# Date
# 29/08/2014       37.40       555.0  59.358289  40.641711
# 05/09/2014       45.84       703.0  61.343805  38.656195
# 08/09/2014       49.36       773.0  62.641815  37.358185
# 12/09/2014       51.48       809.0  62.859363  37.140637
# 16/09/2014       58.56       950.0  64.890710  35.109290

# %%
import pandas as pd
import matplotlib.pyplot as plt

link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)

SL.isnull().sum()
SL["No. of confirmed cases"].mean()


Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

recuperados=((100-PIvsD)/100)*SL['No. of confirmed cases']
SL["recuprados"]=recuperados
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 29/08/2014                     935                    380.0       561.0
# 05/09/2014                    1146                    443.0       687.6
# 08/09/2014                    1234                    461.0       740.4
# 12/09/2014                    1287                    478.0       772.2
# 16/09/2014                    1464                    514.0       878.4
#
#             Female Cases    Boys   Girls  Adult Male  Adult Female  Old Male  \
# Date
# 29/08/2014         374.0  168.30  112.20      336.60        224.40     56.10
# 05/09/2014         458.4  206.28  137.52      412.56        275.04     68.76
# 08/09/2014         493.6  222.12  148.08      444.24        296.16     74.04
# 12/09/2014         514.8  231.66  154.44      463.32        308.88     77.22
# 16/09/2014         585.6  263.52  175.68      527.04        351.36     87.84
#
#             Old Female  recuprados
# Date
# 29/08/2014       37.40       555.0
# 05/09/2014       45.84       703.0
# 08/09/2014       49.36       773.0
# 12/09/2014       51.48       809.0
# 16/09/2014       58.56       950.0

# %%
SL["PR"]=(100-PIvsD)
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  Male Cases  \
# Date
# 29/08/2014                     935                    380.0       561.0
# 05/09/2014                    1146                    443.0       687.6
# 08/09/2014                    1234                    461.0       740.4
# 12/09/2014                    1287                    478.0       772.2
# 16/09/2014                    1464                    514.0       878.4
#
#             Female Cases    Boys   Girls  Adult Male  Adult Female  Old Male  \
# Date
# 29/08/2014         374.0  168.30  112.20      336.60        224.40     56.10
# 05/09/2014         458.4  206.28  137.52      412.56        275.04     68.76
# 08/09/2014         493.6  222.12  148.08      444.24        296.16     74.04
# 12/09/2014         514.8  231.66  154.44      463.32        308.88     77.22
# 16/09/2014         585.6  263.52  175.68      527.04        351.36     87.84
#
#             Old Female  recuprados         PR
# Date
# 29/08/2014       37.40       555.0  59.358289
# 05/09/2014       45.84       703.0  61.343805
# 08/09/2014       49.36       773.0  62.641815
# 12/09/2014       51.48       809.0  62.859363
# 16/09/2014       58.56       950.0  64.890710

# %%
PIvsD=100*SL["No. of confirmed deaths"]/SL["No. of confirmed cases"]

PIvsD_mean=SL['PIvsD'].mean()
PR_mean=SL["PR"].mean()
porcentaje=[PIvsD_mean, PR_mean]
etiquetas=["PIvsD", "PR"]

plt.pie(porcentaje, labels=etiquetas, autopct="%0.1f %%", colors=["purple", "pink"])
plt.axis("equal")
plt.title("Porcentaje de Recuperados")
plt.show()

# %% [markdown]
# # Nueva sección
