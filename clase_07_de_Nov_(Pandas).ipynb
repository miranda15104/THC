# %% [markdown]
# <a href="https://colab.research.google.com/github/miranda15104/THC/blob/main/clase_07_de_Nov_(Pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv
#
# le das esto una antes de acceder al archivo coppy link address

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# 2014-09-05                    362.0
# ...                             ...
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0
#
# [2484 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)
df.info() #cotenido del archivo y cuanto pesa

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df.head()  #saca los primeros 5
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29        Guinea                   482.0                    287.0
# 2014-08-29       Nigeria                    15.0                      6.0
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-08-29       Liberia                   322.0                    225.0
# 2014-09-05        Guinea                   604.0                    362.0

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df.tail() #saca los ultimosz 5
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df.isnull() #no sirve tanto
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-08-29    False                   False                    False
# 2014-09-05    False                   False                    False
# ...             ...                     ...                      ...
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                     True
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
# 2016-03-23    False                   False                    False
#
# [2484 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df.isnull().sum()   #debemos llenar esos espa<cios vacios
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df['Country']#country lo sacas de google colab  esto te sirve para ver los datos paises que tienes
# Out:
# Date
# 2014-08-29                      Guinea
# 2014-08-29                     Nigeria
# 2014-08-29                Sierra Leone
# 2014-08-29                     Liberia
# 2014-09-05                      Guinea
#                         ...
# 2016-03-23                     Liberia
# 2016-03-23                       Italy
# 2016-03-23                     Liberia
# 2016-03-23                     Nigeria
# 2016-03-23    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df['Country'].isin(["mexico"])
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df['Country'].isin(["mexico"]).sum()   #para ver si no esta algo ahi
# Out:
# 0

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

df["Country"]=="Sierra Leone"
# Out:
# Date
# 2014-08-29    False
# 2014-08-29    False
# 2014-08-29     True
# 2014-08-29    False
# 2014-09-05    False
#               ...
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# 2016-03-23    False
# Name: Country, Length: 2484, dtype: bool

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"] #usas una mascara buleana para carcar base vde datos

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1) #quitar del eje 1 counttry
SL.head() #para ver emcavezados
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                   935.0                    380.0
# 2014-09-05                  1146.0                    443.0
# 2014-09-08                  1234.0                    461.0
# 2014-09-12                  1287.0                    478.0
# 2014-09-16                  1464.0                    514.0

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL.head
# Out:
# <bound method NDFrame.head of                  Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Sierra Leone                   935.0                    380.0
# 2014-09-05  Sierra Leone                  1146.0                    443.0
# 2014-09-08  Sierra Leone                  1234.0                    461.0
# 2014-09-12  Sierra Leone                  1287.0                    478.0
# 2014-09-16  Sierra Leone                  1464.0                    514.0
# ...                  ...                     ...                      ...
# 2015-12-17  Sierra Leone                  8704.0                   3589.0
# 2015-12-22  Sierra Leone                  8704.0                   3589.0
# 2015-12-23  Sierra Leone                  8704.0                   3589.0
# 2015-12-29  Sierra Leone                  8704.0                   3589.0
# 2016-03-23  Sierra Leone                  8704.0                   3589.0
#
# [259 rows x 3 columns]>

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.shape #tamaño de la base 259 datos y 2 columnas
# Out:
# (259, 2)

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)

SL.isnull().sum() #para ver datos faltantes
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)

SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed deaths"].mean() #el texto muertes lo buscas, esta en inglees
# Out:
# 3081.019305019305

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed cases"].mean()
# Out:
# 7883.671814671815

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed cases"].mean()


Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

plt.plot(Dates, NCC, "*--r",ms=5, label="infectados")
plt.plot(Dates,NCD, "*-b",  ms=5, label="decesos")
plt.grid()

plt.title("Avance de Ebola en Sierra Leona")
plt.ylabel("casos confirmados")
plt.xlabel("periodo de tiempo ")
plt.xticks(rotation=90, fontsize=10)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed cases"].mean()


Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

PIvsD=100*SL["No. of confirmed deaths"]/SL["No. of confirmed cases"]
PIvsD  #PARA AGREGAR AL DATA FRAME SE USA EL SL
# Out:
# Date
# 2014-08-29    40.641711
# 2014-09-05    38.656195
# 2014-09-08    37.358185
# 2014-09-12    37.140637
# 2014-09-16    35.109290
#                 ...
# 2015-12-17    41.233915
# 2015-12-22    41.233915
# 2015-12-23    41.233915
# 2015-12-29    41.233915
# 2016-03-23    41.233915
# Length: 259, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed cases"].mean()


Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

plt.plot(Dates, NCC, "*--r",ms=5, label="infectados")
plt.plot(Dates,NCD, "*-b",  ms=5, label="decesos")
plt.grid()

plt.title("Avance de Ebola en Sierra Leona")
plt.ylabel("casos confirmados")
plt.xlabel("periodo de tiempo ")
plt.xticks(rotation=90, fontsize=10)
plt.legend()
plt.show()


PIvsD=100*SL["No. of confirmed deaths"]/SL["No. of confirmed cases"]
SL["PIvsD"]=PIvsD  #PARA AGREGAR AL DATA FRAME SE USA EL SL
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed cases"].mean()


Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

PIvsD=100*SL["No. of confirmed deaths"]/SL["No. of confirmed cases"]
SL["PIvsD"]=PIvsD  #PARA AGREGAR AL DATA FRAME SE USA EL SL
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths      PIvsD
# Date
# 2014-08-29                   935.0                    380.0  40.641711
# 2014-09-05                  1146.0                    443.0  38.656195
# 2014-09-08                  1234.0                    461.0  37.358185
# 2014-09-12                  1287.0                    478.0  37.140637
# 2014-09-16                  1464.0                    514.0  35.109290

# %%
import pandas as pd
import matplotlib.pyplot as plt


link='https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv'
code= "?raw=true"
url=link+code
df = pd.read_csv(url,sep=',',index_col=1)

SL=df[df["Country"]=="Sierra Leone"]
SL=SL.drop("Country",axis=1)
SL.fillna(0.0, inplace=True) #para llenar los datos faltantes

SL.isnull().sum()
SL["No. of confirmed cases"].mean()


Dates=SL.index[0:-1:10] #selecciona del primero al ultimo y va de 10 en 10
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

recuperados=((100-PIvsD)/100)*SL['No. of confirmed cases']
SL["recuprados"]=recuperados
SL.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths  recuprados
# Date
# 2014-08-29                   935.0                    380.0       555.0
# 2014-09-05                  1146.0                    443.0       703.0
# 2014-09-08                  1234.0                    461.0       773.0
# 2014-09-12                  1287.0                    478.0       809.0
# 2014-09-16                  1464.0                    514.0       950.0
